# %% [markdown]
# ## W9A16

# %% [markdown]
# ## W9A17

# %% [markdown]
# ## W9A18

# %% [markdown]
# ## W9A19

# %% [markdown]
# ## W9A20

# %% [markdown]
# ## W9A21

# %% [markdown]
# ## W9A22

# %% [markdown]
# ## W9A23

# %% [markdown]
# ## W9A24

# %% [markdown]
# ## W9A25

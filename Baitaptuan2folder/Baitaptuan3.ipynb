# %% [markdown]
# ## W3A1

# %%
a=int(input())
while a!=0:
    print(a%10, end="")
    a//=10
# Out:
# 321

# %% [markdown]
# ## W3A2

# %%
a=int(input())
b=int(input())
a=a^b
b=a^b
a=a^b
print(a,b)
# Out:
# 432 321

# %% [markdown]
# ## W3A3

# %%
n=int(input())
b=[]
while n!=0:
    b.append(n%2)
    n//=2
print(*b[::-1], sep="")
# Out:
# 110

# %%
n=float(input())
k=int(input())
a=10**k
if n*a-int(n*a)>=0.5:
    print((int(n*a)+1)/a)
else:
    print(int(n*a)/a)
# Out:
# 3.67

# %%
n=int(input())
if n&(n-1)==0:
    print("YES")
else:
    print("NO")
# Out:
# YES

# %% [markdown]
# ## W3A4

# %%
a=list(map(int,input().split()))
ma=a[0]
for i in a[1:]:
    if i>ma:
        ma=i
print(ma)
# Out:
# 6

# %%
m=int(input())
n=int(input())
print(m//n)
# Out:
# 1

# %% [markdown]
# ## W3A5

# %%
m=int(input())
if m**0.5==int(m**0.5):
    print("YES")
else:
    print("NO")
# Out:
# NO

# %%
m=int(input())
n=int(input())
print(int(m/n)+1)
# Out:
# 2

# %% [markdown]
# ## W3A6

# %%
n=int(input())
if n%2==0: 
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %% [markdown]
# ## W3A7

# %%
a,b=map(int,input().split())
if a*b>0 and a+b<0:
    print("YES")
else:
    print("NO")
# Out:
# NO

# %% [markdown]
# ## W3A8

# %%
a,b=input().split()
if len(a)>len(b):
    print("YES")
else:
    print("NO")
# Out:
# YES

# %% [markdown]
# ## W3A9

# %%
a,b,c=map(int,input().split())
if a+b>c and a+c>b and b+c>a:
    print("YES")
else:
    print("NO")

# %% [markdown]
# ## W3A10

# %%
a=list(map(int,input().split()))
ma=a[0]
for i in a[1:]:
    if i>ma:
        ma=i
print(ma)

# %% [markdown]
# ## W3A11

# %%
a,b,c=map(int,input().split())
if a+b>c and a+c>b and b+c>a:
    if a==b and b==c:
        print("Tam giac deu")
    elif a==b or b==c or a==c:
        print("Tam giac can")
    else:
        print("Tam giac thuong")
else:
    print("Khong phai tam giac")
# Out:
# Tam giac thuong

# %% [markdown]
# ## W3A12

# %%
n=int(input())
if (n%4 and n%100) or not n%400:
    print("YES")
else:
    print("NO")
# Out:
# NO

# %% [markdown]
# ## W3A13

# %%
n=int(input())
if n<=50:
    print(n**1500)
elif n<100:
    print(75000+(n-50)*2000)
else:
    print(175000+(n-100)*3000)
# Out:
# 235000

# %% [markdown]
# ## W3A14

# %%
a,b=map(float,input().split())
if a!=0:
    print(-b/a)
else:
    if b==0:
        print("Vo so nghiem")
    else:
        print("Vo nghiem")
# Out:
# 1.0

# %% [markdown]
# ## W3A15

# %%
n=float(input())
if n<5:
    print("YEU")
elif n<6.5:
    print("TB")
elif n<8:
    print("KHA")
else:
    print("GIOI")
# Out:
# GIOI

# %% [markdown]
# ## W3A16

# %%
n=float(input())
k=0
if n>0:
    if n-int(n)>0.5:
        k=int(n)+1
    else:
        k=int(n)
    print(int(n)+1,int(n),k)
else:
    if int(n)-n>0.5:
         k=int(n)-1
    else:
        k=int(n)
    print(int(n),int(n)-1,k)
# Out:
# -5 -6 -6

# %% [markdown]
# ## W3A17

# %%
a,b,c,d=map(int,input().split())
k=b/a
if b*k==c and c*k==d:
    print("YES")
else:
    print("NO")
# Out:
# YES

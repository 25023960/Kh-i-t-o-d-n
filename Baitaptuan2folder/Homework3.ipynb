# %% [markdown]
# ## W1

# %%
a,b=map(int,input().split())
print(a*b,(a+b)*2)
# Out:
# 18 18

# %% [markdown]
# ## W2

# %%
a=int(input())
print(3.14*a**2,2*3.14*a)
# Out:
# 28.26 18.84

# %% [markdown]
# ## W3

# %%
a,b,c=map(int,input().split())
d=False
if a+b>c and a+c>b and b+c>a:
    if a==b and b==c:
        print("Tam giac deu")
        d=True
    elif a==b or b==c or a==c:
        print("Tam giac can")
        d=True
    if a**2+b**2==c**2 or a**2+c**2==b**2 or b**2 +c**2 ==a**2:
        print("Tam giac vuong")
        d=True
    if d==False:
        print("Tam giac thuong")
    p=(a+b+c)/2
    print((p*(p-a)*(p-b)*(p-c))**0.5)
else:
    print("Khong phai tam giac")
# Out:
# Tam giac vuong
# 6.0

# %% [markdown]
# ## W4

# %%
a,b=map(float,input().split())
if a!=0:
    print(-b/a)
else:
    if b==0:
        print("Vo so nghiem")
    else:
        print("Vo nghiem")
# Out:
# -0.6666666666666666

# %% [markdown]
# ## W5

# %%
a,b,c=map(int,input().split())
if a==0:
    if b!=0:
        print(-c.b)
    else:
        if c==0:
            print("Vo so nghiem")
        else:
            print("Vo nghiem")
else:
    d=b**2-4*a*c
    if d<0:
        print("Vo nghiem")
    else:
        print((-b+d**0.5)/(2*a),(-b-d**0.5)/(2*a))
# Out:
# Vo nghiem

# %% [markdown]
# ## W6

# %%
a=list(map(float,input().split()))
ma=a[0]
for i in a[1:]:
    if i>ma:
        ma=i
print(ma)
# Out:
# 6.0

# %% [markdown]
# ## W7

# %%
a=list(map(float,input().split()))
mi=a[0]
for i in a[1:]:
    if i<mi:
        mi=i
print(mi)
# Out:
# 1.0

# %% [markdown]
# ## W8

# %%
a,b,m,c,d,n=map(float,input().split())
D=a*d-b*c
D1=m*d-n*c
D2=a*n-c*m
if D==0:
    print("He phuong trinh vo nghiem")
else:
    print(D1/D,D2/D)
# Out:
# 6.833333333333333 1.5

# %% [markdown]
# ## W9

# %%
x=int(input())
gio=x//3600
phut=(x%3600)//60
giay=x%3600%60
print(gio,phut,giay)
# Out:
# 1 40 0

# %% [markdown]
# ## W10

# %%
o1,o2,r,x,y=map(float,input().split())
if (x-o2)**2+(y-o2)**2<=r**2:
    print("Thuoc")
else:
    print("Khong thuoc")
# Out:
# Thuoc

# %% [markdown]
# ## W11

# %%
x,y=map(float,input().split())
print(x**y)
# Out:
# 133.63359999999997

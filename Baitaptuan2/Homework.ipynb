# %% [markdown]
# ## B1

# %%
n=int(input())
print(n*2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 n=int(input())
#       2 print(n*2)
#
# ValueError: invalid literal for int() with base 10: ' f f a 41 4 fa fga  5325 gaga 41 fa 4 14 af a 41'

# %% [markdown]
# ## B2

# %%
a,b=map(float,input().split())
print("{:.2f}".format(a*b-(a/2)**2*3.14))
# Out:
# 10.93

# %% [markdown]
# ## B3

# %%
a=input()
if "a"<=a<="z":
    print(a.upper())
else:
    print(a.lower())
# Out:
# B

# %% [markdown]
# ## B4

# %%
a=input()
if "a"<=a<="z" or "A"<=a<="Z":
    print(f"{a} là kí tu alphabet")
else:
    print(f"{a} không phải là kí tự alphabet")
# Out:
# 78 không phải là kí tự alphabet

# %% [markdown]
# ## B5

# %%
n=input()
if "A"<=n<="Z":
    print(chr(ord(n)+31))
elif "A"==n:
    print("Dac biet")
else:
    print("Input khong phai la chu cai hoa.")
# Out:
# a

# %% [markdown]
# ## B6

# %%
a,b,c=map(float,input().split())
if a+b>c and a+c>b and b+c>a:
    p=(a+b+c)/2
    print("{:.1f}".format((p*(p-a)*(p-b)*(p-c))**0.5))
else:
    print("Khong phai 3 canh cua tam giac")
# Out:
# 6.0

# %% [markdown]
# ## B7

# %%
a=input().split()
print(a[4],a[8])
# Out:
# e i

# %% [markdown]
# ## B8

# %%
n=input()
a=int(input())
b=int(input())
c=b-a
if 0<=c<=50:
    print(n)
    print(round(c*1.08))
elif 50<c<=100:
    print(n)
    print(round(1.08*(99200+(c-50)*2050)))
elif 100<c<=200:
    print(n)
    print(round(1.08*(201700+(c-100)*2380)))
elif 200<c<=300:
    print(n)
    print(round(1.08*(439700+(c-200)*2998)))
elif 300<c<=400:
    print(n)
    print(round(1.08*(739500+(c-300)*3350)))
else:
    print(n)
    print(round(1.08*(1074500+(c-400)*3460)))
# Out:
# Nguyen Xuan Hai
# 1855505

# %% [markdown]
# ## B1

# %%
n=int(input())
if n%2==0:
    print("Chan")
else:
    print("Le")
# Out:
# Chan

# %% [markdown]
# ## B2

# %%
n=int(input())
if n%10==5:
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# ## B3

# %%
n=int(input())
if n%15==0:
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# ## B4

# %%
n=int(input())
if 2026-n>=18:
    print("Du tuoi")
else:
    print("Khong du tuoi")
# Out:
# Du tuoi

# %% [markdown]
# ## B5

# %%
a,b=map(float,input().split())
if a>b:
    print(a)
elif a<b:
    print(b)
else:
    print("Bang nhau")
# Out:
# 36.0

# %% [markdown]
# ## B6

# %%
n=input()
if n.isdigit():
    print("SO")
else:
    print("Chu")
# Out:
# Chu

# %% [markdown]
# ## B7

# %%
n=float(input())
if n<5:
    print("Yeu")
elif 5<=n<6.5:
    print("Trung binh")
elif 6.5<=n<8:
    print("Kha")
elif n>=8:
    print("Gioi")
# Out:
# Yeu

# %% [markdown]
# ## B8

# %%
n=int(input())
if (n%100==0 and n%4!=0) or (n%400==0):
    print("Nam nhuan")
else:
    print("Khong phai nam nhuan")
# Out:
# Khong phai nam nhuan

# %% [markdown]
# ## B9

# %%
n=int(input())
match n:
    case 0:
        print("Khong")
    case 1:
        print("Mot")
    case 2:
        print("Hai")
    case 3:
        print("Ba")
    case 4:
        print("Bon")
    case 5:
        print("Nam")
    case 6:
        print("Sau")
    case 7:
        print("Bay")
    case 8:
        print("Tam")
    case 9:
        print("Chin")
# Out:
# Tam

# %% [markdown]
# ## B10

# %%
n=float(input())
if n>=4:
    print("Qua mon")
else:
    print("Hoc lai")
# Out:
# Hoc lai

# %% [markdown]
# ## B11

# %%
n=int(input())
k=2025-n
print(k)
if k>=18:
    print("Du")
else:
    print("Ko du")
# Out:
# 19
# Du

# %% [markdown]
# ## W2A1: In ra dòng Hello world

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ## W2A2
# Hàm input() trong Python là một hàm dùng để nhận dữ liệu từ người dùng thông qua bàn
# phím, hàm này luôn trả về dữ liệu kiểu chuỗi (str).
# Viết chương trình nhận đầu vào là tên người từ bàn phím và in ra màn hình lời chào tương
# ứng

# %%
ten=input()
print("Hello",ten)
# Out:
# Hello

# %% [markdown]
# ## W2A3

# %%
a,b=map(int,input().split())
print(a+b)
print(a-b)
print(a*b)
print(a//b)
print(a%b)
print(a/b)
# Out:
# 9
# 1
# 20
# 1
# 1
# 1.25

# %% [markdown]
# ## W2A4

# %%
a1, b1, c1, a2, b2, a3=map(int,input().split())
print("{:.1f}".format((a1+b1+c1) + (a2+b2)*2 + (a3*3) / 6))
# Out:
# 272.0

# %% [markdown]
# ## W2A5

# %%
a,b=map(int,input().split())
print(a**b)
# Out:
# 9

# %% [markdown]
# ## W2A6

# %%
a=input()
print(ord(a))
print(a.upper())
# Out:
# 98
# B

# %% [markdown]
# ## W2A7

# %%
print((13**2)*3+5)
print(13**2*3+5)
# Out:
# 512
# 512

# %% [markdown]
# ## W2A8

# %%
a=int(input())
print(1.8*a+32)
# Out:
# 37.4

# %% [markdown]
# ## W2A9

# %%
a=int(input())
print(10+a*1.4)
# Out:
# 14.2

# %% [markdown]
# ## W2A10

# %%
a=input()
print(f"Hello {a}")
# Out:
# Hello Bao Dat kahn

# %% [markdown]
# ## W2A11

# %%
a,b=map(int,input().split())
print(a*3600+b*60)
# Out:
# 11160

# %% [markdown]
# ## W2A12

# %%
a=int(input())
print(a**2*6)
# Out:
# 54

# %% [markdown]
# ## W2A13

# %%
a,b=map(int,input().split())
print((a*b)%10)
# Out:
# 5

# %% [markdown]
# ## W2A14

# %%
a,b=map(int,input().split())
print(b,a)
# Out:
# 18 30

# %% [markdown]
# ## W2A15

# %%
a=int(input())
print("*"*a)
# Out:
# *****

# %% [markdown]
# ## W2A16

# %%
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %% [markdown]
# ## W2A17

# %%
n=int(input())
for i in range(1,n+1):
    print("*"*i)
# Out:
# *
# **
# ***

# %% [markdown]
# ## W2A18

# %%
print("### # #  ### ###")
print(" #  #  #  #   #")
print(" #  #   # #   #")
print(" #  #  #  #   #")
print(" #  # #   #   #")
# Out:
# ### # #  ### ###
#  #  #  #  #   #
#  #  #   # #   #
#  #  #  #  #   #
#  #  # #   #   #

# %% [markdown]
# ## W2A19

# %%
print("Monday")
print("Tuesday")
print("Wednesday")
print("Thursday")
print("Friday")
print("Saturday")
print("Sunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %% [markdown]
# ## W2A20

# %%
print("January")
print("February")
print("March")
print("April")
print("May")
print("June")
print("July")
print("August")
print("September")
print("October")
print("November")
print("December")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %% [markdown]
# ## W2A21

# %%
for i in range(10):
    print("Hello World!")
# Out:
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
